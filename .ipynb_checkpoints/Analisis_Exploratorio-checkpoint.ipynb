# %%
# !pip install --upgrade pip
# !pip install palmerpenguins==0.1.4 numpy pandas seaborn==0.12.1 matplotlib==3.5.3 empiricaldist==0.6.7 statsmodels==0.13.5 scikit-learn==1.0.2 pyjanitor==0.23.1 session-info
# Out:
# Requirement already satisfied: pip in c:\users\usuario\anaconda3\lib\site-packages (23.0.1)
# Requirement already satisfied: palmerpenguins==0.1.4 in c:\users\usuario\anaconda3\lib\site-packages (0.1.4)
# Requirement already satisfied: numpy in c:\users\usuario\anaconda3\lib\site-packages (1.21.5)
# Requirement already satisfied: pandas in c:\users\usuario\anaconda3\lib\site-packages (1.4.2)
# Collecting seaborn==0.12.1
#   Using cached seaborn-0.12.1-py3-none-any.whl (288 kB)
# Requirement already satisfied: matplotlib==3.5.3 in c:\users\usuario\anaconda3\lib\site-packages (3.5.3)
# Requirement already satisfied: empiricaldist==0.6.7 in c:\users\usuario\anaconda3\lib\site-packages (0.6.7)
# Requirement already satisfied: statsmodels==0.13.5 in c:\users\usuario\anaconda3\lib\site-packages (0.13.5)
# Requirement already satisfied: scikit-learn==1.0.2 in c:\users\usuario\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: pyjanitor==0.23.1 in c:\users\usuario\anaconda3\lib\site-packages (0.23.1)
# Requirement already satisfied: session-info in c:\users\usuario\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib==3.5.3) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib==3.5.3) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib==3.5.3) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib==3.5.3) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib==3.5.3) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib==3.5.3) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib==3.5.3) (0.11.0)
# Requirement already satisfied: scipy>=1.3 in c:\users\usuario\anaconda3\lib\site-packages (from statsmodels==0.13.5) (1.7.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\usuario\anaconda3\lib\site-packages (from statsmodels==0.13.5) (0.5.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\usuario\anaconda3\lib\site-packages (from scikit-learn==1.0.2) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from scikit-learn==1.0.2) (2.2.0)
# Requirement already satisfied: natsort in c:\users\usuario\anaconda3\lib\site-packages (from pyjanitor==0.23.1) (8.2.0)
# Requirement already satisfied: multipledispatch in c:\users\usuario\anaconda3\lib\site-packages (from pyjanitor==0.23.1) (0.6.0)
# Requirement already satisfied: pandas-flavor in c:\users\usuario\anaconda3\lib\site-packages (from pyjanitor==0.23.1) (0.5.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: stdlib-list in c:\users\usuario\anaconda3\lib\site-packages (from session-info) (0.8.0)
# Requirement already satisfied: six in c:\users\usuario\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels==0.13.5) (1.16.0)
# Requirement already satisfied: xarray in c:\users\usuario\anaconda3\lib\site-packages (from pandas-flavor->pyjanitor==0.23.1) (0.20.1)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas-flavor->pyjanitor==0.23.1) (0.1)
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# Successfully installed seaborn-0.12.1

# %% [markdown]
# **Importando librerías**

# %%
import empiricaldist
import janitor
import matplotlib.pyplot as plt
import numpy as np
import palmerpenguins
import pandas as pd
import scipy.stats
import seaborn as sns
import sklearn.metrics
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats as ss
import session_info

# %% [markdown]
# **Estableciendo apariencia de los gráficos**

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11, 9.4)

penguin_color = {
    'Adelie': '#ff6602ff',
    'Gentoo': '#0f7175ff',
    'Chinstrap': '#c65dc9ff'
}

# %% [markdown]
# **Cargando datos**

# %%
raw_penguin_df = palmerpenguins.load_penguins_raw()
raw_penguin_df.head(2)
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN

# %%
preprocess_penguin_df = palmerpenguins.load_penguins()
preprocess_penguin_df.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007

# %% [markdown]
# **Tipos de datos de las variables**

# %%
preprocess_penguin_df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# year                   int64
# dtype: object

# %% [markdown]
# **Variables por cada tipo dato**

# %%
(
    preprocess_penguin_df
    .dtypes
    .value_counts()
)
# Out:
# float64    4
# object     3
# int64      1
# dtype: int64

# %% [markdown]
# **Cantidad de variables y observaciones**

# %%
preprocess_penguin_df.shape
# Out:
# (344, 8)

# %% [markdown]
# **¿Existen valores nulos?**

# %%
(
    preprocess_penguin_df
    .isnull()
    .any()
)
# Out:
# species              False
# island               False
# bill_length_mm        True
# bill_depth_mm         True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# year                 False
# dtype: bool

# %% [markdown]
# **¿Cuántos valores nulos tengo por cada variable?**

# %%
(
    preprocess_penguin_df
    .isnull()
    .sum()
)
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# **Proporción de valores nulos por cada variable**

# %%
(
    preprocess_penguin_df
    .isnull()
    .melt()
    .pipe(
        lambda df: (
            sns.displot(
            data = df,
            y = 'variable',
            hue = 'value',
            multiple = 'fill',
            aspect=2)
        )
    )
)

# %% [markdown]
# **¿Cómo puedo visualizar los valores nulos en todo el conjunto de datos?**

# %%
(
    preprocess_penguin_df
    .isnull()
    .transpose()
    .pipe(
        lambda df: (
            sns.heatmap(
            data = df
            )
        )
    )
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Teniendo en cuenta que observamos que la mayoría de datos faltantes provienen de un solo pingûino,
# podemos contemplar la opción de eliminar dichas observaciones del análisis, pero primero es importante
# identificar cuántas observaciones perdemos si optamos por este camino.

# %% [markdown]
# **¿Cuántas observaciones perdemos si eliminamos los datos faltantes?**

# %%
process_penguin_df = (
    preprocess_penguin_df
    .dropna()
)

process_penguin_df.head(3)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007

# %% [markdown]
# **Conteos y proporciones**

# %% [markdown]
# ¿Qué estadísticos describen el conjunto de datos?

# %% [markdown]
#
#   **Todas las variables**

# %%
process_penguin_df.describe(include = 'all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      333     333      333.000000     333.000000         333.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       146     163             NaN            NaN                NaN
# mean       NaN     NaN       43.992793      17.164865         200.966967
# std        NaN     NaN        5.468668       1.969235          14.015765
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.500000      15.600000         190.000000
# 50%        NaN     NaN       44.500000      17.300000         197.000000
# 75%        NaN     NaN       48.600000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex         year
# count    333.000000   333   333.000000
# unique          NaN     2          NaN
# top             NaN  male          NaN
# freq            NaN   168          NaN
# mean    4207.057057   NaN  2008.042042
# std      805.215802   NaN     0.812944
# min     2700.000000   NaN  2007.000000
# 25%     3550.000000   NaN  2007.000000
# 50%     4050.000000   NaN  2008.000000
# 75%     4775.000000   NaN  2009.000000
# max     6300.000000   NaN  2009.000000

# %% [markdown]
# **Análisis variables numéricas**

# %%
process_penguin_df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   333.000000
# mean   2008.042042
# std       0.812944
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# **Análisis variables categóricas**

# %%
process_penguin_df.describe(include = 'object')
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  male
# freq       146     163   168

# %% [markdown]
# *Convirtiendo mis variables categóricas a tipo categoría*

# %%
(
    process_penguin_df
    .astype({
        'species':'category',
        'island':'category',
        'sex':'category'
    }
    )
    .dtypes
)
# Out:
# species              category
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                  category
# year                    int64
# dtype: object

# %% [markdown]
# **Visualizando los conteos con pandas**

# %%
(
    process_penguin_df
    .species
    .value_counts()
    .plot(
    kind= 'bar'
    )
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Visualizando los conteos con Seaborn**

# %%
sns.catplot(
    data = process_penguin_df,
    x = 'species',
    kind = 'count',
    palette = penguin_color
)

# %%
(
    process_penguin_df
    .value_counts('species', sort = True)
    .reset_index(name= 'count')
    .pipe(
        lambda df: (
            sns.barplot(
                data=df,
                x='species',
                y='count',
                palette=penguin_color)
        )
            
        )
)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %% [markdown]
# **¿Cómo visualizamos las proporciones**

# %%
(
    process_penguin_df
    .add_column('X', '')
    .pipe(
        lambda df: (
            sns.displot(
                data = df,
                x = 'X',
                hue = 'species',
                multiple = 'fill',
                palette = penguin_color
            )
        )
    )

)

# %% [markdown]
# **Analizando la varioable Island en cuanto a cantidad y proporción**

# %%
sns.catplot(
    data = process_penguin_df,
    x = 'island',
    kind = 'count',
)

# %%
(
    process_penguin_df
    .add_column('X', '')
    .pipe(
        lambda df:
            sns.displot(
                data = df,
                x = 'X',
                hue = 'island',
                multiple = 'fill'
            )
    )
)

# %% [markdown]
# **Por último, analizamos la variable Sex y sus proporciones**

# %%
sns.catplot(
    data = process_penguin_df,
    x = 'sex',
    kind = 'count'
    
)

# %%
(
    process_penguin_df
    .add_column('X', '')
    .pipe(
        lambda df: 
            sns.displot(
                data = df,
                x = 'X',
                hue = 'sex',
                multiple = 'fill'
            )
    )

)

# %% [markdown]
# **Medidas de Tendencia Central**

# %% [markdown]
# ***Media***

# %%
process_penguin_df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
process_penguin_df[['bill_length_mm', 'bill_depth_mm',
       'flipper_length_mm', 'body_mass_g']].mean()
# Out:
# bill_length_mm         43.992793
# bill_depth_mm          17.164865
# flipper_length_mm     200.966967
# body_mass_g          4207.057057
# dtype: float64

# %% [markdown]
# ***Mediana***

# %%
process_penguin_df[['bill_length_mm', 'bill_depth_mm',
       'flipper_length_mm', 'body_mass_g']].median()
# Out:
# bill_length_mm         44.5
# bill_depth_mm          17.3
# flipper_length_mm     197.0
# body_mass_g          4050.0
# dtype: float64

# %% [markdown]
# ***Moda***

# %%
process_penguin_df.mode()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Biscoe            41.1           17.0              190.0
#
#    body_mass_g   sex  year
# 0       3800.0  male  2009

# %% [markdown]
# **Medidas de dispersión**

# %% [markdown]
# *Valor máximo de las variables*

# %%
process_penguin_df.max(numeric_only = True)
# Out:
# bill_length_mm         59.6
# bill_depth_mm          21.5
# flipper_length_mm     231.0
# body_mass_g          6300.0
# year                 2009.0
# dtype: float64

# %%
process_penguin_df.min(numeric_only = True)
# Out:
# bill_length_mm         32.1
# bill_depth_mm          13.1
# flipper_length_mm     172.0
# body_mass_g          2700.0
# year                 2007.0
# dtype: float64

# %%
#Rango

process_penguin_df.max(numeric_only = True) - process_penguin_df.min(numeric_only = True)
# Out:
# bill_length_mm         27.5
# bill_depth_mm           8.4
# flipper_length_mm      59.0
# body_mass_g          3600.0
# year                    2.0
# dtype: float64

# %% [markdown]
# *Desviación estándar*

# %%
process_penguin_df.std(numeric_only = True)
# Out:
# bill_length_mm         5.468668
# bill_depth_mm          1.969235
# flipper_length_mm     14.015765
# body_mass_g          805.215802
# year                   0.812944
# dtype: float64

# %% [markdown]
# **Rango Intercuartil**

# %%
process_penguin_df.quantile(0.75) - process_penguin_df.quantile(0.25)
# Out:
# bill_length_mm          9.1
# bill_depth_mm           3.1
# flipper_length_mm      23.0
# body_mass_g          1225.0
# year                    2.0
# dtype: float64

# %%
(
    process_penguin_df
    .quantile(q=[0.75, 0.50, 0.25])
    .transpose()
    .rename_axis('variable')
    .reset_index()
    .assign(
        iqr =  lambda df: df[0.75] - df[0.25]
    )
)
# Out:
#             variable    0.75     0.5    0.25     iqr
# 0     bill_length_mm    48.6    44.5    39.5     9.1
# 1      bill_depth_mm    18.7    17.3    15.6     3.1
# 2  flipper_length_mm   213.0   197.0   190.0    23.0
# 3        body_mass_g  4775.0  4050.0  3550.0  1225.0
# 4               year  2009.0  2008.0  2007.0     2.0

# %% [markdown]
# **Visualizando la distribución de las variables**

# %%
numeric_columns = process_penguin_df.select_dtypes(include=np.number).columns

fig, ax = plt.subplots(1, len(numeric_columns), figsize=(15,5))

for i in range(len(numeric_columns)):
    sns.histplot(
        ax = ax[i],
        data = process_penguin_df,
        x = numeric_columns[i],
        multiple = 'stack',
        hue = 'species',
        bins = 15,
        palette = penguin_color,
        kde = 'true'
    )

# %%
sns.histplot(
    data = process_penguin_df,
    x= 'flipper_length_mm',
    hue = 'species',
    palette = penguin_color,
    kde = True,
    bins = 15
)


plt.axvline(
    x = process_penguin_df.flipper_length_mm.mean(),
    color = 'red',
    linestyle = 'dashed',
    linewidth = 2
)
plt.axvline(
    x = process_penguin_df.flipper_length_mm.median(),
    color = 'green',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.flipper_length_mm.quantile(0.25),
    color = 'blue',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.flipper_length_mm.quantile(0.75),
    color = 'black',
    linestyle = 'dashed',
    linewidth = 2
)

plt.title('Fliper Length', loc = 'left')
plt.text(process_penguin_df.flipper_length_mm.mean(), 53, 'Mean', fontsize=12, color = 'red')
plt.text(process_penguin_df.flipper_length_mm.median(), 53, 'Median', fontsize=10, color = 'green')
plt.text(process_penguin_df.flipper_length_mm.quantile(0.25), 53, 'Q(25%)', fontsize=12, color = 'blue')
plt.text(process_penguin_df.flipper_length_mm.quantile(0.75), 53, 'Q(75%)', fontsize=12, color = 'black')
# Out:
# Text(213.0, 53, 'Q(75%)')

# %%
sns.histplot(
    data = process_penguin_df,
    x= 'bill_length_mm',
    hue = 'species',
    palette = penguin_color,
    kde = True,
    bins = 15
)


plt.axvline(
    x = process_penguin_df.bill_length_mm.mean(),
    color = 'red',
    linestyle = 'dashed',
    linewidth = 2
)
plt.axvline(
    x = process_penguin_df.bill_length_mm.median(),
    color = 'green',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.bill_length_mm.quantile(0.25),
    color = 'blue',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.bill_length_mm.quantile(0.75),
    color = 'black',
    linestyle = 'dashed',
    linewidth = 2
)

plt.title('Bill Lenght', loc = 'left')
plt.text(process_penguin_df.bill_length_mm.mean(), 45, 'Mean', fontsize=12, color = 'red')
plt.text(process_penguin_df.bill_length_mm.median(), 43, 'Median', fontsize=10, color = 'green')
plt.text(process_penguin_df.bill_length_mm.quantile(0.25), 45, 'Q(25%)', fontsize=12, color = 'blue')
plt.text(process_penguin_df.bill_length_mm.quantile(0.75), 45, 'Q(75%)', fontsize=12, color = 'black')
# Out:
# Text(48.6, 45, 'Q(75%)')

# %%
sns.histplot(
    data = process_penguin_df,
    x= 'bill_depth_mm',
    hue = 'species',
    palette = penguin_color,
    kde = True,
    bins = 15
)


plt.axvline(
    x = process_penguin_df.bill_depth_mm.mean(),
    color = 'red',
    linestyle = 'dashed',
    linewidth = 2
)
plt.axvline(
    x = process_penguin_df.bill_depth_mm.median(),
    color = 'green',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.bill_depth_mm.quantile(0.25),
    color = 'blue',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.bill_depth_mm.quantile(0.75),
    color = 'black',
    linestyle = 'dashed',
    linewidth = 2
)

plt.title('Bill Depth mm', loc = 'left')

plt.text(process_penguin_df.bill_depth_mm.mean(), 41, 'Mean', fontsize=12, color = 'red')
plt.text(process_penguin_df.bill_depth_mm.median(), 38, 'Median', fontsize=10, color = 'green')
plt.text(process_penguin_df.bill_depth_mm.quantile(0.25), 41, 'Q(25%)', fontsize=12, color = 'blue')
plt.text(process_penguin_df.bill_depth_mm.quantile(0.75), 41, 'Q(75%)', fontsize=12, color = 'black')
# Out:
# Text(18.7, 41, 'Q(75%)')

# %%
sns.histplot(
    data = process_penguin_df,
    x= 'body_mass_g',
    hue = 'species',
    palette = penguin_color,
    kde = True,
    bins = 15
)


plt.axvline(
    x = process_penguin_df.body_mass_g.mean(),
    color = 'red',
    linestyle = 'dashed',
    linewidth = 2
)
plt.axvline(
    x = process_penguin_df.body_mass_g.median(),
    color = 'green',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.body_mass_g.quantile(0.25),
    color = 'blue',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.body_mass_g.quantile(0.75),
    color = 'black',
    linestyle = 'dashed',
    linewidth = 2
)

plt.title('Bill Depth mm', loc = 'left')

plt.text(process_penguin_df.body_mass_g.mean(), 31, 'Mean', fontsize=12, color = 'red')
plt.text(process_penguin_df.body_mass_g.median(), 31, 'Median', fontsize=10, color = 'green')
plt.text(process_penguin_df.body_mass_g.quantile(0.25), 31, 'Q(25%)', fontsize=12, color = 'blue')
plt.text(process_penguin_df.body_mass_g.quantile(0.75), 31, 'Q(75%)', fontsize=12, color = 'black')
# Out:
# Text(4775.0, 31, 'Q(75%)')

# %%
sns.boxplot(
    data = process_penguin_df,
    x = 'flipper_length_mm'
)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm'>

# %%
sns.boxplot(
    data = process_penguin_df,
    x = 'flipper_length_mm',
    y = 'species',
    palette = penguin_color
)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='species'>
