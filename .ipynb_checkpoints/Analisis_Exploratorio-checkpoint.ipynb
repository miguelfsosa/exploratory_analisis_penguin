# %%
# !pip install --upgrade pip
# !pip install palmerpenguins==0.1.4 numpy pandas seaborn==0.12.1 matplotlib==3.5.3 empiricaldist==0.6.7 statsmodels==0.13.5 scikit-learn==1.0.2 pyjanitor==0.23.1 session-info
# Out:
# Requirement already satisfied: pip in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (23.0.1)
# Requirement already satisfied: palmerpenguins==0.1.4 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: numpy in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (1.21.5)
# Requirement already satisfied: pandas in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (1.4.4)
# Requirement already satisfied: seaborn==0.12.1 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (0.12.1)
# Requirement already satisfied: matplotlib==3.5.3 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (3.5.3)
# Requirement already satisfied: empiricaldist==0.6.7 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (0.6.7)
# Requirement already satisfied: statsmodels==0.13.5 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (0.13.5)
# Requirement already satisfied: scikit-learn==1.0.2 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (1.0.2)
# Requirement already satisfied: pyjanitor==0.23.1 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (0.23.1)
# Requirement already satisfied: session-info in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.3) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.3) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.3) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.3) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.3) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.3) (4.25.0)
# Requirement already satisfied: patsy>=0.5.2 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from statsmodels==0.13.5) (0.5.2)
# Requirement already satisfied: scipy>=1.3 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from statsmodels==0.13.5) (1.9.1)
# Requirement already satisfied: joblib>=0.11 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from scikit-learn==1.0.2) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from scikit-learn==1.0.2) (2.2.0)
# Requirement already satisfied: natsort in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from pyjanitor==0.23.1) (8.2.0)
# Requirement already satisfied: pandas-flavor in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from pyjanitor==0.23.1) (0.5.0)
# Requirement already satisfied: multipledispatch in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from pyjanitor==0.23.1) (0.6.0)
# Requirement already satisfied: pytz>=2020.1 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: stdlib-list in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from session-info) (0.8.0)
# Requirement already satisfied: six in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels==0.13.5) (1.16.0)
# Requirement already satisfied: lazy-loader>=0.1 in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from pandas-flavor->pyjanitor==0.23.1) (0.1)
# Requirement already satisfied: xarray in /home/miguelsosa/anaconda3/lib/python3.9/site-packages (from pandas-flavor->pyjanitor==0.23.1) (0.20.1)

# %% [markdown]
# **Importando librerías**

# %%
import empiricaldist
import janitor
import matplotlib.pyplot as plt
import numpy as np
import palmerpenguins
import pandas as pd
import scipy.stats
import seaborn as sns
import sklearn.metrics
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats as ss
import session_info

# %% [markdown]
# **Estableciendo apariencia de los gráficos**

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (8, 5)

penguin_color = {
    'Adelie': '#ff6602ff',
    'Gentoo': '#0f7175ff',
    'Chinstrap': '#c65dc9ff'
}

# %% [markdown]
# **Cargando datos**

# %%
raw_penguin_df = palmerpenguins.load_penguins_raw()
raw_penguin_df.head(2)
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN

# %%
preprocess_penguin_df = palmerpenguins.load_penguins()
preprocess_penguin_df.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007

# %% [markdown]
# **Tipos de datos de las variables**

# %%
preprocess_penguin_df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# year                   int64
# dtype: object

# %% [markdown]
# **Variables por cada tipo dato**

# %%
(
    preprocess_penguin_df
    .dtypes
    .value_counts()
)
# Out:
# float64    4
# object     3
# int64      1
# dtype: int64

# %% [markdown]
# **Cantidad de variables y observaciones**

# %%
preprocess_penguin_df.shape
# Out:
# (344, 8)

# %% [markdown]
# **¿Existen valores nulos?**

# %%
(
    preprocess_penguin_df
    .isnull()
    .any()
)
# Out:
# species              False
# island               False
# bill_length_mm        True
# bill_depth_mm         True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# year                 False
# dtype: bool

# %% [markdown]
# **¿Cuántos valores nulos tengo por cada variable?**

# %%
(
    preprocess_penguin_df
    .isnull()
    .sum()
)
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# **Proporción de valores nulos por cada variable**

# %%
(
    preprocess_penguin_df
    .isnull()
    .melt()
    .pipe(
        lambda df: (
            sns.displot(
            data = df,
            y = 'variable',
            hue = 'value',
            multiple = 'fill',
            aspect=2)
        )
    )
)

# %% [markdown]
# **¿Cómo puedo visualizar los valores nulos en todo el conjunto de datos?**

# %%
(
    preprocess_penguin_df
    .isnull()
    .transpose()
    .pipe(
        lambda df: (
            sns.heatmap(
            data = df
            )
        )
    )
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Teniendo en cuenta que observamos que la mayoría de datos faltantes provienen de un solo pingûino,
# podemos contemplar la opción de eliminar dichas observaciones del análisis, pero primero es importante
# identificar cuántas observaciones perdemos si optamos por este camino.

# %% [markdown]
# **¿Cuántas observaciones perdemos si eliminamos los datos faltantes?**

# %%
process_penguin_df = (
    preprocess_penguin_df
    .dropna()
)

process_penguin_df.head(3)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007

# %% [markdown]
# **Conteos y proporciones**

# %% [markdown]
# ¿Qué estadísticos describen el conjunto de datos?

# %% [markdown]
#
#   **Todas las variables**

# %%
process_penguin_df.describe(include = 'all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      333     333      333.000000     333.000000         333.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       146     163             NaN            NaN                NaN
# mean       NaN     NaN       43.992793      17.164865         200.966967
# std        NaN     NaN        5.468668       1.969235          14.015765
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.500000      15.600000         190.000000
# 50%        NaN     NaN       44.500000      17.300000         197.000000
# 75%        NaN     NaN       48.600000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex         year
# count    333.000000   333   333.000000
# unique          NaN     2          NaN
# top             NaN  male          NaN
# freq            NaN   168          NaN
# mean    4207.057057   NaN  2008.042042
# std      805.215802   NaN     0.812944
# min     2700.000000   NaN  2007.000000
# 25%     3550.000000   NaN  2007.000000
# 50%     4050.000000   NaN  2008.000000
# 75%     4775.000000   NaN  2009.000000
# max     6300.000000   NaN  2009.000000

# %% [markdown]
# **Análisis variables numéricas**

# %%
process_penguin_df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   333.000000
# mean   2008.042042
# std       0.812944
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# **Análisis variables categóricas**

# %%
process_penguin_df.describe(include = 'object')
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  male
# freq       146     163   168

# %% [markdown]
# *Convirtiendo mis variables categóricas a tipo categoría*

# %%
(
    process_penguin_df
    .astype({
        'species':'category',
        'island':'category',
        'sex':'category'
    }
    )
    .dtypes
)
# Out:
# species              category
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                  category
# year                    int64
# dtype: object

# %% [markdown]
# **Visualizando los conteos con pandas**

# %%
(
    process_penguin_df
    .species
    .value_counts()
    .plot(
    kind= 'bar'
    )
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Visualizando los conteos con Seaborn**

# %%
sns.catplot(
    data = process_penguin_df,
    x = 'species',
    kind = 'count',
    palette = penguin_color
)

# %%
(
    process_penguin_df
    .value_counts('species', sort = True)
    .reset_index(name= 'count')
    .pipe(
        lambda df: (
            sns.barplot(
                data=df,
                x='species',
                y='count',
                palette=penguin_color)
        )
            
        )
)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %% [markdown]
# **¿Cómo visualizamos las proporciones**

# %%
(
    process_penguin_df
    .add_column('X', '')
    .pipe(
        lambda df: (
            sns.displot(
                data = df,
                x = 'X',
                hue = 'species',
                multiple = 'fill',
                palette = penguin_color
            )
        )
    )

)

# %% [markdown]
# **Analizando la varioable Island en cuanto a cantidad y proporción**

# %%
sns.catplot(
    data = process_penguin_df,
    x = 'island',
    kind = 'count',
)

# %%
(
    process_penguin_df
    .add_column('X', '')
    .pipe(
        lambda df:
            sns.displot(
                data = df,
                x = 'X',
                hue = 'island',
                multiple = 'fill'
            )
    )
)

# %% [markdown]
# **Por último, analizamos la variable Sex y sus proporciones**

# %%
sns.catplot(
    data = process_penguin_df,
    x = 'sex',
    kind = 'count'
    
)

# %%
(
    process_penguin_df
    .add_column('X', '')
    .pipe(
        lambda df: 
            sns.displot(
                data = df,
                x = 'X',
                hue = 'sex',
                multiple = 'fill'
            )
    )

)

# %% [markdown]
# **Medidas de Tendencia Central**

# %% [markdown]
# ***Media***

# %%
process_penguin_df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
process_penguin_df[['bill_length_mm', 'bill_depth_mm',
       'flipper_length_mm', 'body_mass_g']].mean()
# Out:
# bill_length_mm         43.992793
# bill_depth_mm          17.164865
# flipper_length_mm     200.966967
# body_mass_g          4207.057057
# dtype: float64

# %% [markdown]
# ***Mediana***

# %%
process_penguin_df[['bill_length_mm', 'bill_depth_mm',
       'flipper_length_mm', 'body_mass_g']].median()
# Out:
# bill_length_mm         44.5
# bill_depth_mm          17.3
# flipper_length_mm     197.0
# body_mass_g          4050.0
# dtype: float64

# %% [markdown]
# ***Moda***

# %%
process_penguin_df.mode()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Biscoe            41.1           17.0              190.0
#
#    body_mass_g   sex  year
# 0       3800.0  male  2009

# %% [markdown]
# **Medidas de dispersión**

# %% [markdown]
# *Valor máximo de las variables*

# %%
process_penguin_df.max(numeric_only = True)
# Out:
# bill_length_mm         59.6
# bill_depth_mm          21.5
# flipper_length_mm     231.0
# body_mass_g          6300.0
# year                 2009.0
# dtype: float64

# %%
process_penguin_df.min(numeric_only = True)
# Out:
# bill_length_mm         32.1
# bill_depth_mm          13.1
# flipper_length_mm     172.0
# body_mass_g          2700.0
# year                 2007.0
# dtype: float64

# %%
#Rango

process_penguin_df.max(numeric_only = True) - process_penguin_df.min(numeric_only = True)
# Out:
# bill_length_mm         27.5
# bill_depth_mm           8.4
# flipper_length_mm      59.0
# body_mass_g          3600.0
# year                    2.0
# dtype: float64

# %% [markdown]
# *Desviación estándar*

# %%
process_penguin_df.std(numeric_only = True)
# Out:
# bill_length_mm         5.468668
# bill_depth_mm          1.969235
# flipper_length_mm     14.015765
# body_mass_g          805.215802
# year                   0.812944
# dtype: float64

# %% [markdown]
# **Rango Intercuartil**

# %%
process_penguin_df.quantile(0.75) - process_penguin_df.quantile(0.25)
# Out:
# bill_length_mm          9.1
# bill_depth_mm           3.1
# flipper_length_mm      23.0
# body_mass_g          1225.0
# year                    2.0
# dtype: float64

# %%
(
    process_penguin_df
    .quantile(q=[0.75, 0.50, 0.25])
    .transpose()
    .rename_axis('variable')
    .reset_index()
    .assign(
        iqr =  lambda df: df[0.75] - df[0.25]
    )
)
# Out:
#             variable    0.75     0.5    0.25     iqr
# 0     bill_length_mm    48.6    44.5    39.5     9.1
# 1      bill_depth_mm    18.7    17.3    15.6     3.1
# 2  flipper_length_mm   213.0   197.0   190.0    23.0
# 3        body_mass_g  4775.0  4050.0  3550.0  1225.0
# 4               year  2009.0  2008.0  2007.0     2.0

# %% [markdown]
# **Visualizando la distribución de las variables**

# %%
numeric_columns = process_penguin_df.select_dtypes(include=np.number).columns

fig, ax = plt.subplots(1, len(numeric_columns), figsize=(15,5))

for i in range(len(numeric_columns)):
    sns.histplot(
        ax = ax[i],
        data = process_penguin_df,
        x = numeric_columns[i],
        multiple = 'stack',
        hue = 'species',
        bins = 15,
        palette = penguin_color,
        kde = 'true'
    )

# %%
sns.histplot(
    data = process_penguin_df,
    x= 'flipper_length_mm',
    hue = 'species',
    palette = penguin_color,
    kde = True,
    bins = 15
)


plt.axvline(
    x = process_penguin_df.flipper_length_mm.mean(),
    color = 'red',
    linestyle = 'dashed',
    linewidth = 2
)
plt.axvline(
    x = process_penguin_df.flipper_length_mm.median(),
    color = 'green',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.flipper_length_mm.quantile(0.25),
    color = 'blue',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.flipper_length_mm.quantile(0.75),
    color = 'black',
    linestyle = 'dashed',
    linewidth = 2
)

plt.title('Fliper Length', loc = 'left')
plt.text(process_penguin_df.flipper_length_mm.mean(), 53, 'Mean', fontsize=12, color = 'red')
plt.text(process_penguin_df.flipper_length_mm.median(), 53, 'Median', fontsize=10, color = 'green')
plt.text(process_penguin_df.flipper_length_mm.quantile(0.25), 53, 'Q(25%)', fontsize=12, color = 'blue')
plt.text(process_penguin_df.flipper_length_mm.quantile(0.75), 53, 'Q(75%)', fontsize=12, color = 'black')
# Out:
# Text(213.0, 53, 'Q(75%)')

# %%
sns.histplot(
    data = process_penguin_df,
    x= 'bill_length_mm',
    hue = 'species',
    palette = penguin_color,
    kde = True,
    bins = 15
)


plt.axvline(
    x = process_penguin_df.bill_length_mm.mean(),
    color = 'red',
    linestyle = 'dashed',
    linewidth = 2
)
plt.axvline(
    x = process_penguin_df.bill_length_mm.median(),
    color = 'green',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.bill_length_mm.quantile(0.25),
    color = 'blue',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.bill_length_mm.quantile(0.75),
    color = 'black',
    linestyle = 'dashed',
    linewidth = 2
)

plt.title('Bill Lenght', loc = 'left')
plt.text(process_penguin_df.bill_length_mm.mean(), 45, 'Mean', fontsize=12, color = 'red')
plt.text(process_penguin_df.bill_length_mm.median(), 43, 'Median', fontsize=10, color = 'green')
plt.text(process_penguin_df.bill_length_mm.quantile(0.25), 45, 'Q(25%)', fontsize=12, color = 'blue')
plt.text(process_penguin_df.bill_length_mm.quantile(0.75), 45, 'Q(75%)', fontsize=12, color = 'black')
# Out:
# Text(48.6, 45, 'Q(75%)')

# %%
sns.histplot(
    data = process_penguin_df,
    x= 'bill_depth_mm',
    hue = 'species',
    palette = penguin_color,
    kde = True,
    bins = 15
)


plt.axvline(
    x = process_penguin_df.bill_depth_mm.mean(),
    color = 'red',
    linestyle = 'dashed',
    linewidth = 2
)
plt.axvline(
    x = process_penguin_df.bill_depth_mm.median(),
    color = 'green',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.bill_depth_mm.quantile(0.25),
    color = 'blue',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.bill_depth_mm.quantile(0.75),
    color = 'black',
    linestyle = 'dashed',
    linewidth = 2
)

plt.title('Bill Depth mm', loc = 'left')

plt.text(process_penguin_df.bill_depth_mm.mean(), 41, 'Mean', fontsize=12, color = 'red')
plt.text(process_penguin_df.bill_depth_mm.median(), 38, 'Median', fontsize=10, color = 'green')
plt.text(process_penguin_df.bill_depth_mm.quantile(0.25), 41, 'Q(25%)', fontsize=12, color = 'blue')
plt.text(process_penguin_df.bill_depth_mm.quantile(0.75), 41, 'Q(75%)', fontsize=12, color = 'black')
# Out:
# Text(18.7, 41, 'Q(75%)')

# %%
sns.histplot(
    data = process_penguin_df,
    x= 'body_mass_g',
    hue = 'species',
    palette = penguin_color,
    kde = True,
    bins = 15
)


plt.axvline(
    x = process_penguin_df.body_mass_g.mean(),
    color = 'red',
    linestyle = 'dashed',
    linewidth = 2
)
plt.axvline(
    x = process_penguin_df.body_mass_g.median(),
    color = 'green',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.body_mass_g.quantile(0.25),
    color = 'blue',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = process_penguin_df.body_mass_g.quantile(0.75),
    color = 'black',
    linestyle = 'dashed',
    linewidth = 2
)

plt.title('Bill Depth mm', loc = 'left')

plt.text(process_penguin_df.body_mass_g.mean(), 31, 'Mean', fontsize=12, color = 'red')
plt.text(process_penguin_df.body_mass_g.median(), 31, 'Median', fontsize=10, color = 'green')
plt.text(process_penguin_df.body_mass_g.quantile(0.25), 31, 'Q(25%)', fontsize=12, color = 'blue')
plt.text(process_penguin_df.body_mass_g.quantile(0.75), 31, 'Q(75%)', fontsize=12, color = 'black')
# Out:
# Text(4775.0, 31, 'Q(75%)')

# %%
sns.boxplot(
    data = process_penguin_df,
    x = 'flipper_length_mm'
)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm'>

# %%
sns.boxplot(
    data = process_penguin_df,
    x = 'flipper_length_mm',
    y = 'species',
    palette = penguin_color
)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='species'>

# %% [markdown]
# **Aplicando funciones de probabilidad**

# %% [markdown]
# ***Funciones de probabilidad de masas (PMFs)***

# %% [markdown]
# *Utilizando Seaborn*

# %%
sns.histplot(
    data = process_penguin_df,
    x = 'flipper_length_mm',
    binwidth = 1,
    stat = 'probability'  #Con este parámetro las barras ya no muestran el conteo sino que representan la probabilidad
)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Probability'>

# %% [markdown]
# *Utilizando Empiricaldist*

# %%
pmf_flipper_length_mm = empiricaldist.Pmf.from_seq(
    process_penguin_df.flipper_length_mm,
    normalize = True
)

# %%
pmf_flipper_length_mm.bar() #Graficando las probabilidades desde el método bar

# %%
pmf_flipper_length_mm(190) #Puedo preguntar la probabilidad de encontrar un valor determinado
# Out:
# 0.06306306306306306

# %% [markdown]
# **Funciones empíricas de probabilidad acumulada (ECDFS)**

# %% [markdown]
# *Utilizando Seaborn*

# %%
sns.ecdfplot(
    data = process_penguin_df,
    x = 'flipper_length_mm'
)

#Esta gráfica nos muestra la probabilidad acumulada, es decir, qué tan probable es encontrar un valor menor o igual a X medida
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Proportion'>

# %% [markdown]
# *Utilizando EmpiricalDist*

# %%
cdf_flipper_length_mm = empiricaldist.Cdf.from_seq(
    process_penguin_df.flipper_length_mm,
    normalize = True
)

# %%
cdf_flipper_length_mm.plot()
# Out:
# <AxesSubplot:>

# %%
def graf_prob_acum(columna, medida):
    
    cdf_variable = empiricaldist.Cdf.from_seq(
    process_penguin_df[columna],
    normalize = True
    )
    
    cdf_variable.plot()

    q = medida
    p = cdf_variable.forward(q)
    
    plt.title(columna, loc = 'left')

    plt.vlines(
        x=q,
        ymin=0,
        ymax=p,
        color='black',
        linestyle='dashed'
    )

    plt.hlines(
        y=p,
        xmin=cdf_variable.qs[0],
        xmax=q,
        color='black',
        linestyle='dashed'
    )

    plt.plot(q,p, 'ro')

# %%
print(graf_prob_acum('body_mass_g', 3500))
# Out:
# None

# %% [markdown]
# **Comparando distribuciones**

# %%
sns.ecdfplot(
    data = process_penguin_df,
    x = 'flipper_length_mm',
    hue = 'species',
    palette = penguin_color
)

#Distribución acumulada de probabilidad de cada una de las especies
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Proportion'>

# %% [markdown]
# **Funciones de densidad de probabilidad**

# %%
sns.kdeplot(
    data = process_penguin_df,
    x = 'flipper_length_mm',
    #hue = 'species',
    bw_method = 0.1 #Modifica el ancho de la banda
)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Density'>

# %%
stats = process_penguin_df.body_mass_g.describe()
stats
# Out:
# count     333.000000
# mean     4207.057057
# std       805.215802
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4775.000000
# max      6300.000000
# Name: body_mass_g, dtype: float64

# %%
xs = np.linspace(stats['min'], stats['max'])
ys = scipy.stats.norm(stats['mean'], stats['std']).cdf(xs)

plt.plot(xs, ys, color = 'black', linestyle = 'dashed')

#La línea punteada muestra el comportamiento de las probabilidades si los datos siguieran una distribución normal
#Graficamos la función de probabilidad acumulada

empiricaldist.Cdf.from_seq(
    process_penguin_df.body_mass_g,
    normalize = True
).plot() #Línea azul
# Out:
# <AxesSubplot:>

# %%
xs = np.linspace(stats['min'], stats['max'])
ys = scipy.stats.norm(stats['mean'], stats['std']).pdf(xs)

plt.plot(xs, ys, color = 'black', linestyle = 'dashed')

#La línea punteada muestra el comportamiento de las probabilidades si los datos siguieran una distribución normal
#Graficamos la función de probabilidad acumulada

sns.kdeplot(
    data = process_penguin_df,
    x = 'body_mass_g'
)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# A partir de estos dos contrastes entre la distribución teórica y la real,
# observamos que nuestros datos sobre el peso no siguen precisamente una distribución normal,
# pues presentan un sesgo a la izquierda.

# %% [markdown]
# **Ley de los grandes números**

# %%
process_penguin_df.sex.value_counts(normalize = True)
# Out:
# male      0.504505
# female    0.495495
# Name: sex, dtype: float64

# %%
sex_numeric = process_penguin_df.sex.replace(['male', 'female'], [0, 1])

# %%
number_samples = 100
sample_size = 35

samples_df = pd.DataFrame()

np.random.seed(42)

for i in range(1, number_samples + 1):
    sex_numeric_sample = sex_numeric.sample(sample_size, replace = True).to_numpy()
    sample_name = f"sample{i}"
    samples_df[sample_name] = sex_numeric_sample

male_population_mean = samples_df.mean().mean()

print(f"Porcentaje estimado de pinguinos machos en la población es: {male_population_mean * 100:.4f}%")
# Out:
# Porcentaje estimado de pinguinos machos en la población es: 50.0857%

# %%
sample_means_binomial = pd.DataFrame(samples_df.mean(), columns =['sample_mean'])
sns.kdeplot(data = sample_means_binomial)
plt.axvline(x = sex_numeric.mean(), color = 'r', linestyle = '--')

# %% [markdown]
# **Análisis bivariado**

# %% [markdown]
# **Estableciendo relaciones: Gráficos de puntos**

# %%
sns.scatterplot(data = process_penguin_df,
            x = 'bill_length_mm',
            y = 'bill_depth_mm',
            hue = 'species',
            palette = penguin_color
            )
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
#General

sns.displot(
    data = process_penguin_df,
    x= 'bill_length_mm',
    y= 'bill_depth_mm'
)

# %%
sns.jointplot(
    data =  process_penguin_df,
    x = 'bill_length_mm',
    y = 'bill_depth_mm'
)

# %%
#Analizando relaciones del tamaño de los picos según la especie
(
    sns.FacetGrid(
        process_penguin_df,
        col = 'species',
        hue = 'sex'
    )
    .map(
        sns.scatterplot,
        'bill_length_mm',
        'bill_depth_mm',
        alpha = 0.5
    )
    .add_legend()

)

# %%
#Analizando relaciones entre el peso y el tamaño de las alas según la especie y diferenciado por sexo
(
    sns.FacetGrid(
        process_penguin_df,
        col = 'species',
        hue = 'sex'
    )
    .map(
        sns.scatterplot,
        'body_mass_g',
        'flipper_length_mm',
        alpha = 0.5
    )
    .add_legend()

)

# %% [markdown]
# **Esableciendo relaciones: Gráficos de Violín y Boxplots**

# %%
sns.scatterplot(
    data = process_penguin_df,
    x = 'species',
    y = 'flipper_length_mm',
    hue = 'sex',
    color = penguin_color
)
# Out:
# <AxesSubplot:xlabel='species', ylabel='flipper_length_mm'>

# %%
#Añadiendo ruido para visualizar mejor los puntos:

sns.stripplot(
    data = process_penguin_df,
    x = 'species',
    y = 'flipper_length_mm',
    hue = 'sex'
)
# Out:
# <AxesSubplot:xlabel='species', ylabel='flipper_length_mm'>

# %%
ax= sns.boxplot(
    data = process_penguin_df,
    x = 'flipper_length_mm',
    y = 'species',
    #hue = 'species',
    palette = penguin_color
)

#Añadiendo puntos para visualizar mejor la distribución

ax = sns.stripplot(
    data = process_penguin_df,
    x = 'flipper_length_mm',
    y = 'species',
    color = '.3'
)

# %%
ax = sns.violinplot(
    data = process_penguin_df,
    x = 'species',
    y = 'flipper_length_mm',
    #hue = 'species',
    palette = penguin_color
)


ax = sns.stripplot(
    data = process_penguin_df,
    x = 'species',
    y = 'flipper_length_mm',
    color = '.3'
)

# %%
sns.swarmplot(
    data = process_penguin_df,
    x = 'species',
    y = 'flipper_length_mm',
    hue = 'species',
    palette = penguin_color
)
# Out:
# <AxesSubplot:xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# **Estableciendo relaciones: Matrices de correlación**

# %%
process_penguin_df.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
# year                     0.032657      -0.048182           0.151068
#
#                    body_mass_g      year
# bill_length_mm        0.589451  0.032657
# bill_depth_mm        -0.472016 -0.048182
# flipper_length_mm     0.872979  0.151068
# body_mass_g           1.000000  0.021862
# year                  0.021862  1.000000

# %%
sns.heatmap(
    process_penguin_df.corr(),
    cmap = sns.diverging_palette(20, 230, as_cmap = True),
    center = 0,
    vmin =-1,
    vmax = 1,
    linewidths = 0.5,
    annot = True
)
# Out:
# <AxesSubplot:>

# %%
#Ordena las variables de modo tal que las mayores correlaciones se agrupen

sns.clustermap(
    process_penguin_df.corr(),
    cmap = sns.diverging_palette(20, 230, as_cmap = True),
    center = 0,
    vmin =-1,
    vmax = 1,
    linewidths = 0.5,
    annot = True
)

# %% [markdown]
# **¿Hay alguna correlación con el sexo de los pingüinos?** Para averiguarlo debemos agregar una columna de sexo representado de forma numérica:

# %%
process_penguin_df = (
    process_penguin_df.assign(
        numeric_sex = lambda df: df.sex.replace(['female', 'male'], [0, 1])
                             )
)

# %%
#Graficamos nuevamente el Clustermap para analizar la correlación de las variables con el sexo

sns.clustermap(
    process_penguin_df.corr(),
    cmap = sns.diverging_palette(20, 230, as_cmap = True),
    center = 0,
    vmin =-1,
    vmax = 1,
    linewidths = 0.5,
    annot = True
)

# %% [markdown]
# **Estableciendo relaciones: Análisis de Regresión Simple**

# %%
sns.scatterplot(
    data = process_penguin_df,
    x = 'bill_length_mm',
    y = 'bill_depth_mm'
)

res_bill_penguins = scipy.stats.linregress(
    x = process_penguin_df.bill_length_mm,
    y = process_penguin_df.bill_depth_mm
)

print(res_bill_penguins)

fx_1 = np.array([process_penguin_df.bill_length_mm.min(), process_penguin_df.bill_length_mm.max()])
fy_1 = res_bill_penguins.intercept + res_bill_penguins.slope * fx_1

plt.plot(fx_1, fy_1)
# Out:
# LinregressResult(slope=-0.08232675339862275, intercept=20.786648668433827, rvalue=-0.22862563591302898, pvalue=2.5282897209443435e-05, stderr=0.019268346735778864, intercept_stderr=0.8541730787409804)

# %%
#Graficando la regresión directamente con Seaborn

sns.lmplot(
    data = process_penguin_df,
    x = 'bill_length_mm',
    y = 'bill_depth_mm',
    height = 10,
    hue = 'species'
)

# %%
#Regresión lineal entre el peso y el tamaño de las alas

sns.scatterplot(
    data = process_penguin_df,
    x = 'body_mass_g',
    y = 'flipper_length_mm'
)


reg_body_flip = scipy.stats.linregress(
    x = process_penguin_df.body_mass_g,
    y= process_penguin_df.flipper_length_mm)

print(reg_body_flip)


eje_x_regress_bf = np.array([process_penguin_df.body_mass_g.min(), process_penguin_df.body_mass_g.max()])
eje_y_regress_bf = reg_body_flip.intercept + reg_body_flip.slope * eje_x_regress_bf

plt.plot(eje_x_regress_bf, eje_y_regress_bf)
# Out:
# LinregressResult(slope=0.015195264815217668, intercept=137.03962089225467, rvalue=0.8729788985653613, pvalue=3.1328362509719978e-105, stderr=0.00046665391049053467, intercept_stderr=1.9987694290243143)

# %%
sns.lmplot(
    data = process_penguin_df,
    x = 'body_mass_g',
    y = 'flipper_length_mm',
    #hue = 'species',
    #palette = penguin_color
)

# %% [markdown]
# **Creando un modelo de Regresión Lineal**

# %%
(
    smf.ols(
        formula = 'body_mass_g ~ flipper_length_mm',
        data = process_penguin_df
    )
    .fit()
    .params
)
# Out:
# Intercept           -5872.092683
# flipper_length_mm      50.153266
# dtype: float64

# %% [markdown]
# **Análisis de regresión múltiple**
#
# Partiendo del supuesto de que no tengo forma de conocer el peso de los próximos pingüinos en nuestro estudio,
# ¿Cómo podría capturar este dato?

# %% [markdown]
# **Creando modelos**

# %% [markdown]
# *Modelo 1*

# %%
model_1 = (
    smf.ols(
    formula = 'body_mass_g ~ bill_length_mm',
    data = process_penguin_df
    ).
    fit()
)

model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            body_mass_g   R-squared:                       0.347
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     176.2
# Date:                Thu, 23 Feb 2023   Prob (F-statistic):           1.54e-32
# Time:                        06:40:07   Log-Likelihood:                -2629.1
# No. Observations:                 333   AIC:                             5262.
# Df Residuals:                     331   BIC:                             5270.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        388.8452    289.817      1.342      0.181    -181.271     958.961
# bill_length_mm    86.7918      6.538     13.276      0.000      73.931      99.652
# ==============================================================================
# Omnibus:                        6.141   Durbin-Watson:                   0.849
# Prob(Omnibus):                  0.046   Jarque-Bera (JB):                4.899
# Skew:                          -0.197   Prob(JB):                       0.0864
# Kurtosis:                       2.555   Cond. No.                         360.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Notas para interpretación: El 86.79 del coeficiente de la longitud del pingüino nos indica que por cada cambio en dicha medida, es decir, en la longitud del pico, esperaríamos un aumento de 86.79 gramos en el peso.

# %%
model_2 = (
    smf.ols(
    formula = 'body_mass_g ~ bill_length_mm + bill_depth_mm',
    data = process_penguin_df
    ).
    fit()
)

model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            body_mass_g   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.464
# Method:                 Least Squares   F-statistic:                     144.8
# Date:                Thu, 23 Feb 2023   Prob (F-statistic):           7.04e-46
# Time:                        06:44:36   Log-Likelihood:                -2595.2
# No. Observations:                 333   AIC:                             5196.
# Df Residuals:                     330   BIC:                             5208.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       3413.4519    437.911      7.795      0.000    2552.002    4274.902
# bill_length_mm    74.8126      6.076     12.313      0.000      62.860      86.765
# bill_depth_mm   -145.5072     16.873     -8.624      0.000    -178.699    -112.315
# ==============================================================================
# Omnibus:                        2.839   Durbin-Watson:                   1.798
# Prob(Omnibus):                  0.242   Jarque-Bera (JB):                2.175
# Skew:                          -0.000   Prob(JB):                        0.337
# Kurtosis:                       2.604   Cond. No.                         644.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model_3 = (
    smf.ols(
    formula = 'body_mass_g ~ bill_length_mm + bill_depth_mm +  flipper_length_mm',
    data = process_penguin_df
    ).
    fit()
)

model_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            body_mass_g   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     354.9
# Date:                Thu, 23 Feb 2023   Prob (F-statistic):          9.26e-103
# Time:                        06:46:13   Log-Likelihood:                -2459.8
# No. Observations:                 333   AIC:                             4928.
# Df Residuals:                     329   BIC:                             4943.
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept         -6445.4760    566.130    -11.385      0.000   -7559.167   -5331.785
# bill_length_mm        3.2929      5.366      0.614      0.540      -7.263      13.849
# bill_depth_mm        17.8364     13.826      1.290      0.198      -9.362      45.035
# flipper_length_mm    50.7621      2.497     20.327      0.000      45.850      55.675
# ==============================================================================
# Omnibus:                        5.596   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.061   Jarque-Bera (JB):                5.469
# Skew:                           0.312   Prob(JB):                       0.0649
# Kurtosis:                       3.068   Cond. No.                     5.44e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.44e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model_4 = (
    smf.ols(
    formula = 'body_mass_g ~ bill_length_mm + bill_depth_mm +  flipper_length_mm + C(sex)',
    data = process_penguin_df
    ).
    fit()
)

model_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            body_mass_g   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     381.3
# Date:                Thu, 23 Feb 2023   Prob (F-statistic):          6.28e-122
# Time:                        06:47:37   Log-Likelihood:                -2411.8
# No. Observations:                 333   AIC:                             4834.
# Df Residuals:                     328   BIC:                             4853.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept         -2288.4650    631.580     -3.623      0.000   -3530.924   -1046.006
# C(sex)[T.male]      541.0285     51.710     10.463      0.000     439.304     642.753
# bill_length_mm       -2.3287      4.684     -0.497      0.619     -11.544       6.886
# bill_depth_mm       -86.0882     15.570     -5.529      0.000    -116.718     -55.459
# flipper_length_mm    38.8258      2.448     15.862      0.000      34.011      43.641
# ==============================================================================
# Omnibus:                        2.598   Durbin-Watson:                   1.843
# Prob(Omnibus):                  0.273   Jarque-Bera (JB):                2.125
# Skew:                           0.062   Prob(JB):                        0.346
# Kurtosis:                       2.629   Cond. No.                     7.01e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.01e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model_5 = (
    smf.ols(
    formula = 'body_mass_g ~ flipper_length_mm + C(sex)',
    data = process_penguin_df
    ).
    fit()
)

model_5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            body_mass_g   R-squared:                       0.806
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     684.8
# Date:                Thu, 23 Feb 2023   Prob (F-statistic):          3.53e-118
# Time:                        07:12:07   Log-Likelihood:                -2427.2
# No. Observations:                 333   AIC:                             4860.
# Df Residuals:                     330   BIC:                             4872.
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept         -5410.3002    285.798    -18.931      0.000   -5972.515   -4848.085
# C(sex)[T.male]      347.8503     40.342      8.623      0.000     268.491     427.209
# flipper_length_mm    46.9822      1.441     32.598      0.000      44.147      49.817
# ==============================================================================
# Omnibus:                        0.262   Durbin-Watson:                   1.710
# Prob(Omnibus):                  0.877   Jarque-Bera (JB):                0.376
# Skew:                           0.051   Prob(JB):                        0.829
# Kurtosis:                       2.870   Cond. No.                     2.95e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.95e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **Visualizando resultados de los Modelos**

# %% [markdown]
# Creación de tabla de resultados.

# %%
model_results = pd.DataFrame(
    dict(
        actual_value = process_penguin_df.body_mass_g,
        prediction_model_1 = model_1.predict(),
        prediction_model_2 = model_2.predict(),
        prediction_model_3 = model_3.predict(),
        prediction_model_4 = model_4.predict(),
        prediction_model_5 = model_5.predict(),
        species = process_penguin_df.species,
        sex = process_penguin_df.sex
    )
)

model_results.head()
# Out:
#    actual_value  prediction_model_1  prediction_model_2  prediction_model_3  \
# 0        3750.0         3782.402961         3617.641192         3204.761227
# 1        3800.0         3817.119665         3836.725580         3436.701722
# 2        3250.0         3886.553073         3809.271371         3906.897032
# 4        3450.0         3574.102738         3350.786581         3816.705772
# 5        3650.0         3799.761313         3356.140070         3696.168128
#
#    prediction_model_4  prediction_model_5 species     sex
# 0         3579.136946         3441.323750  Adelie    male
# 1         3343.220772         3328.384372  Adelie  female
# 2         3639.137335         3751.223949  Adelie  female
# 4         3457.954243         3657.259599  Adelie  female
# 5         3764.536023         3864.163327  Adelie    male

# %% [markdown]
# **Graficando los resultados con la Función de Distribución Acumulada**

# %%
sns.ecdfplot(
    data = model_results
)
# Out:
# <AxesSubplot:ylabel='Proportion'>

# %%
#Graficando solo los datos reales vs el modelo 5

sns.ecdfplot(
    data = model_results.select_columns(['actual_value', 'prediction_model_5'])
)
# Out:
# <AxesSubplot:ylabel='Proportion'>

# %% [markdown]
# **Analizando los resultados desde la Probabilidad de densisad**

# %%
sns.kdeplot(
    data = model_results.select_columns(['actual_value', 'prediction_model_5']),
    #cumulative = True
)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#Froma correcta de hacerlo (para ahorrar más tiempo)

sns.lmplot(
    data = process_penguin_df,
    x = 'flipper_length_mm',
    y = 'body_mass_g',
    hue = 'sex',
    height = 6
)

# %% [markdown]
# **Análisis de Regresión Logística**

# %% [markdown]
# ¿Podemos crear un modelo que nos ayude a definir si un pingüino es macho o hembra?

# %%
model_1_sex= smf.logit(
    formula = 'numeric_sex ~ flipper_length_mm + bill_length_mm + bill_depth_mm + C(island)',
    data = process_penguin_df
).fit()

model_1_sex.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.360900
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            numeric_sex   No. Observations:                  333
# Model:                          Logit   Df Residuals:                      327
# Method:                           MLE   Df Model:                            5
# Date:                Thu, 23 Feb 2023   Pseudo R-squ.:                  0.4793
# Time:                        09:09:54   Log-Likelihood:                -120.18
# converged:                       True   LL-Null:                       -230.80
# Covariance Type:            nonrobust   LLR p-value:                 8.021e-46
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                -61.4464      6.944     -8.849      0.000     -75.057     -47.836
# C(island)[T.Dream]        -1.5596      0.493     -3.163      0.002      -2.526      -0.593
# C(island)[T.Torgersen]    -1.0323      0.599     -1.725      0.085      -2.205       0.141
# flipper_length_mm          0.1393      0.024      5.874      0.000       0.093       0.186
# bill_length_mm             0.1413      0.045      3.150      0.002       0.053       0.229
# bill_depth_mm              1.6401      0.185      8.864      0.000       1.277       2.003
# ==========================================================================================
# """

# %%
model_2_sex= smf.logit(
    formula = 'numeric_sex ~ flipper_length_mm + bill_length_mm',
    data = process_penguin_df
).fit()

model_2_sex.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.630537
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            numeric_sex   No. Observations:                  333
# Model:                          Logit   Df Residuals:                      330
# Method:                           MLE   Df Model:                            2
# Date:                Thu, 23 Feb 2023   Pseudo R-squ.:                 0.09027
# Time:                        09:12:58   Log-Likelihood:                -209.97
# converged:                       True   LL-Null:                       -230.80
# Covariance Type:            nonrobust   LLR p-value:                 8.937e-10
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -7.0060      1.728     -4.055      0.000     -10.392      -3.620
# flipper_length_mm     0.0077      0.011      0.698      0.485      -0.014       0.029
# bill_length_mm        0.1244      0.030      4.212      0.000       0.067       0.182
# =====================================================================================
# """

# %% [markdown]
# ¿Podemos definir un modelo que nos ayude a identificar si un modelo pertenece a una determinada especie?

# %% [markdown]
# Dado que los modelos de Regresión logística son binarios, no puedo definir un modelo que me clasifique un pingüino entre las tres diferentes opciones, lo que puedo hacer es definir un modelo que prediga si un pingüino pertenece o no a una especie determinada.

# %%
process_penguin_df.species.unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
#Para este caso, tomaré la especie Adelie

process_penguin_df = process_penguin_df.assign(
    is_adelie = lambda df: df.species.replace(['Adelie', 'Gentoo', 'Chinstrap'], [1, 0, 0])
)

# %%
model_is_adelie = smf.logit(
    formula = 'is_adelie ~ flipper_length_mm + C(sex)',
    data = process_penguin_df
).fit()

model_is_adelie.params
# Out:
# Optimization terminated successfully.
#          Current function value: 0.355225
#          Iterations 8
# Intercept            40.568368
# C(sex)[T.male]        1.282656
# flipper_length_mm    -0.209705
# dtype: float64

# %%
is_adelie_df_predictions = pd.DataFrame(
    dict(
        actual_adelie = process_penguin_df.is_adelie,
        predicted_values = model_is_adelie.predict().round()
    )
)

is_adelie_df_predictions
# Out:
#      actual_adelie  predicted_values
# 0                1               1.0
# 1                1               1.0
# 2                1               0.0
# 4                1               1.0
# 5                1               1.0
# ..             ...               ...
# 339              0               0.0
# 340              0               0.0
# 341              0               1.0
# 342              0               0.0
# 343              0               0.0
#
# [333 rows x 2 columns]

# %%
(
    is_adelie_df_predictions
    .value_counts(['actual_adelie', 'predicted_values'])
    .reset_index(name = 'count')
)

#El count nos da el resultado de las predicciones de acuerdo al cruce mostrado en la fila
# Out:
#    actual_adelie  predicted_values  count
# 0              0               0.0    151
# 1              1               1.0    129
# 2              0               1.0     36
# 3              1               0.0     17

# %% [markdown]
# Analizando la fiabilidad del modelo con Sklearn

# %%
print(
    sklearn.metrics.confusion_matrix(
        is_adelie_df_predictions.actual_adelie,
        is_adelie_df_predictions.predicted_values
    )
)

sklearn.metrics.accuracy_score(
    is_adelie_df_predictions.actual_adelie,
    is_adelie_df_predictions.predicted_values
)
# Out:
# [[151  36]
#  [ 17 129]]
# 0.8408408408408409

# %% [markdown]
#     Verdadero Negativo (0,0): 151 - El modelo los clasificó como de una especie diferente al Adelie y es correcto
#     Falso Positivo (0,1): 36 (Error Tipo I) - el modelo los clasificó como Adelie y es incorrecto
#     Falso Negativo (1,0): 17 (Error Tipo II) - el modelo los clasificó como de otra especie diferente y son Adelie
#     Verdadero Positivo (1,1): 129 - El modelo los clasificó como Adelie y es correcto

# %%
(
    sns.pairplot(
        data = process_penguin_df,
        hue = 'species',
        palette = penguin_color
    )
)
